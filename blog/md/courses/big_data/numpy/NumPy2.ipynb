# %%
import numpy as np;
M = np.ones((2, 3));
a = np.arange(3);

# %% [markdown]
# M

# %%
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
a
# Out:
# array([0, 1, 2])

# %%
M.shape
# Out:
# (2, 3)

# %%
a.shape
# Out:
# (3,)

# %%
M+a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.]])

# %%
a = np.arange(3).reshape((3, 1))

# %%
b = np.arange(3)

# %%
a
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
b
# Out:
# array([0, 1, 2])

# %%
b.ndim
# Out:
# 1

# %%
a.ndim
# Out:
# 2

# %%
a+b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
M = np.ones((3, 2))

# %%
a = np.arange(3)

# %%
a.shape
# Out:
# (3,)

# %%
a[:, np.newaxis].shape
# Out:
# (3, 1)

# %%
a
# Out:
# array([0, 1, 2])

# %%
a[:, np.newaxis] + M
# Out:
# array([[1., 1.],
#        [2., 2.],
#        [3., 3.]])

# %%
X = np.random.random((10, 3))

# %%
X
# Out:
# array([[0.1442866 , 0.90019336, 0.49564977],
#        [0.42590982, 0.60351257, 0.75878845],
#        [0.46479488, 0.05452814, 0.44001127],
#        [0.03417765, 0.5453941 , 0.72479529],
#        [0.32728906, 0.86558655, 0.74156487],
#        [0.7325961 , 0.79559601, 0.84329662],
#        [0.72386361, 0.54914466, 0.66718576],
#        [0.95538858, 0.45736309, 0.0066414 ],
#        [0.13132358, 0.34560787, 0.23481028],
#        [0.43512951, 0.06211338, 0.44153467]])

# %%
Xmean = X.mean(0)

# %%
Xmean
# Out:
# array([0.43747594, 0.51790397, 0.53542784])

# %%
X[:,0].mean()
# Out:
# 0.4374759382138521

# %%
X[:,1].mean()
# Out:
# 0.5179039729325805

# %%
X[:,2].mean()
# Out:
# 0.5354278372158184

# %%
X
# Out:
# array([[0.1442866 , 0.90019336, 0.49564977],
#        [0.42590982, 0.60351257, 0.75878845],
#        [0.46479488, 0.05452814, 0.44001127],
#        [0.03417765, 0.5453941 , 0.72479529],
#        [0.32728906, 0.86558655, 0.74156487],
#        [0.7325961 , 0.79559601, 0.84329662],
#        [0.72386361, 0.54914466, 0.66718576],
#        [0.95538858, 0.45736309, 0.0066414 ],
#        [0.13132358, 0.34560787, 0.23481028],
#        [0.43512951, 0.06211338, 0.44153467]])

# %%
X.mean()
# Out:
# 0.4969359161207502

# %%
X.mean(0)
# Out:
# array([0.43747594, 0.51790397, 0.53542784])

# %%
X.mean(0).mean()
# Out:
# 0.49693591612075033

# %%
X.mean(1)
# Out:
# array([0.51337658, 0.59607028, 0.3197781 , 0.43478901, 0.64481349,
#        0.79049624, 0.64673134, 0.47313102, 0.23724725, 0.31292585])

# %%
X.mean(1).mean()
# Out:
# 0.4969359161207502

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)[:, np.newaxis]
z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
!%matplotlib inline;
import matplotlib.pyplot as plt;
# Out:
# /bin/bash: line 1: fg: no job control

# %%
plt.imshow(z, origin='lower', extent=[0, 5, 0, 5], cmap='viridis')
